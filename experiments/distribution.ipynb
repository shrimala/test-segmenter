# %%
import pandas as pd
import plotly.express as px
import os
os.chdir("../")
# !pwd
# Out:
# /home/sigmoid/developer/ml_projects/upwork/text_segmenter/text-segmenter

# %%
from glob import glob
files = glob("./experiments/books/**/*.txt")
for file in files:
    break

# %%
def get_paragraphs(file):
    with open(file, "r") as f:
        out = f.read().replace("\n========", "\n\n").split("\n\n")

    output = [x.replace("\n", "") for x in out if len(x.split())>10]
    return output

# %%
print(" files :", len(files))
# Out:
#  files : 269

# %%
output = []
for file in files:
    output +=get_paragraphs(file)

# %%
word_count = [len(x.split(" ")) for x in output]

# %%
df = pd.DataFrame({"paragraph_word_count":word_count})

# %%
fig = px.histogram(df, x="paragraph_word_count", title= f"{len(files)} chapters stats")
fig
# Out:
# <div>                            <div id="4d445c09-3c1f-4479-a2c7-5a1685c77af3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4d445c09-3c1f-4479-a2c7-5a1685c77af3")) {                    Plotly.newPlot(                        "4d445c09-3c1f-4479-a2c7-5a1685c77af3",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"paragraph_word_count=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[169,245,232,123,291,215,135,42,294,324,124,76,208,216,25,249,130,54,61,106,17,390,96,41,114,43,41,90,845,41,57,17,309,117,109,177,54,60,32,80,21,173,91,110,132,207,410,240,368,135,94,130,25,12,39,20,17,35,75,16,86,79,68,99,119,46,144,43,41,69,31,11,68,28,45,59,69,64,32,81,35,54,68,53,56,51,17,53,44,14,35,60,36,25,11,11,36,62,45,104,20,84,43,155,161,108,101,17,22,48,11,54,31,11,122,72,107,195,69,145,11,11,131,74,144,84,84,97,52,52,65,45,174,98,40,115,53,51,59,41,64,144,170,45,26,36,74,151,207,23,60,177,93,76,176,20,292,88,66,167,31,21,114,66,120,44,178,226,94,200,230,18,82,180,128,112,169,241,167,24,166,197,277,195,244,144,117,49,56,76,16,61,92,163,119,173,189,259,65,97,64,65,85,203,38,24,12,28,25,17,24,22,99,26,174,37,64,78,245,41,56,102,38,160,80,100,27,43,215,246,263,115,115,56,37,40,88,56,25,49,103,76,78,196,47,45,73,34,79,69,57,56,75,61,124,92,116,71,135,36,50,27,169,57,22,38,80,54,57,184,499,128,60,22,50,13,29,71,11,39,77,115,150,90,34,95,57,189,102,140,123,86,38,361,40,71,252,128,75,133,39,87,71,85,13,12,13,24,24,64,36,95,193,95,73,50,42,101,119,17,14,12,53,47,34,24,28,22,262,82,209,169,259,69